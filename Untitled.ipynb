# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('image.png')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 948.5, 779.5, -0.5)

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from ipywidgets import IntSlider

# %%
im_gray = cv2.imread('image.png', cv2.IMREAD_GRAYSCALE)
layout = widgets.Layout(width='500px')
@interact(f,thresh=IntSlider(min=0,max=255,step=1,value=165,layout=layout))
def f(thresh):
    #thresh = 153
    im_bw = cv2.threshold(im_gray, thresh, 255, cv2.THRESH_BINARY)[1]
    im_wb = cv2.bitwise_not(im_bw)
    plt.imshow(im_bw,cmap='binary')
    plt.axis('off')

# %%
im_gray = cv2.imread('image2.jpg', cv2.IMREAD_GRAYSCALE)
layout = widgets.Layout(width='500px')
@interact(f,thresh=IntSlider(min=0,max=255,step=1,value=165,layout=layout))
def f(thresh):
    #thresh = 153
    im_bw = cv2.threshold(im_gray, thresh, 255, cv2.THRESH_BINARY)[1]
    im_wb = cv2.bitwise_not(im_bw)
    plt.imshow(im_bw,cmap='binary')
    plt.axis('off')
